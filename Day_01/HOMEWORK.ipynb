# %% [markdown]
# # Day 01 Homework: Add `__pow__`
#
# Implement power for the scalar `Value` class. This notebook explains the task and leaves the implementation cells for you to complete.

# %% [markdown]
# ## Task
#
# Add support for raising a scalar `Value` to a constant power.
#
# The forward rule is simple:
#
# $$x^n$$
#
# The derivative is:
#
# $$\frac{d(x^n)}{dx} = n x^{n-1}$$

# %% [markdown]
# ## Constraints
#
# - Only support numeric exponents.
# - Keep the style consistent with `__add__` and `__mul__`.
# - Accumulate gradients with `+=`.
# - Do not add tensor support here.

# %%
class Value:
    def __init__(self, data, _children=(), _op="", label=""):
        self.data = float(data)
        self.grad = 0.0
        self._prev = set(_children)
        self._op = _op
        self.label = label
        self._backward = lambda: None

    def __repr__(self):
        return f"Value(data={self.data}, grad={self.grad})"

    def __add__(self, other):
        other = other if isinstance(other, Value) else Value(other)
        out = Value(self.data + other.data, (self, other), "+")

        def _backward():
            self.grad += 1.0 * out.grad
            other.grad += 1.0 * out.grad

        out._backward = _backward
        return out

    def __mul__(self, other):
        other = other if isinstance(other, Value) else Value(other)
        out = Value(self.data * other.data, (self, other), "*")

        def _backward():
            self.grad += other.data * out.grad
            other.grad += self.data * out.grad

        out._backward = _backward
        return out

    # TODO: implement __pow__ here
    # Hint: use out = Value(self.data ** other, (self,), f"**{other}")
    # Hint: derivative is n * x ** (n - 1)

# %% [markdown]
# ## Example To Match
#
# When you are done, this should work:
#
# ```python
# x = Value(2.0)
# y = x ** 3
# y.backward()
# print(y.data)  # 8.0
# print(x.grad)  # 12.0
# ```

# %% [markdown]
# ## Stretch
#
# If you finish early, implement division using a negative power.

# %%
# TODO: implement __truediv__ using __pow__
# def __truediv__(self, other):
#     return self * (other ** -1)
