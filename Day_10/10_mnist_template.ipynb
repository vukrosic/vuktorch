# %% [markdown]
# # Day 10: MNIST
#
# **Series:** PyTorch from Scratch: The Zero-to-One Framework
#
# Day 10 is the payoff: an end-to-end run on a real dataset.

# %% [markdown]
# ## Goal
#
# Train the framework on MNIST and show that the whole stack works together.

# %% [markdown]
# ## Big Idea
#
# A real dataset forces the framework to prove that all of the abstractions compose.

# %% [markdown]
# ## Build Here
#
# Write the loading, training, and evaluation steps in a single script.

# %% [markdown]
# ## Exercise
#
# Run the final script and inspect a few predictions by hand.
