# %% [markdown]
# # Day 07: Loss Functions
#
# **Series:** PyTorch from Scratch: The Zero-to-One Framework
#
# Day 07 turns predictions into a training signal.

# %% [markdown]
# ## Goal
#
# Implement MSE first, then cross-entropy for classification.

# %% [markdown]
# ## Big Idea
#
# A loss is just a scalar that tells the model how wrong it is.

# %% [markdown]
# ## Build Here
#
# Write both loss functions and make sure they reduce over a batch.

# %% [markdown]
# ## Exercise
#
# Compare MSE and cross-entropy on the same toy predictions.
